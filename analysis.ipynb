# %%
from src.lane import Lane
from src.dataviz import plot_history

# %%
lane = Lane(100)
lane.next = lane
lane.push([1, 2, 3])

hist = []
for _ in range(1000):
    try:
        lane.step()
        hist.append(list(lane.positions))
    except Exception:
        break

# %%
plot_history(hist)
